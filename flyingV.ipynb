# %%
import json
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException

###########################################################################################################################
main_driver = webdriver.Chrome('C:\chromedriver.exe')

#boards = ['design','freebird','film','tech','art','leisure','citizen','local','sport','game','publish','traveling']
boards = ['design']
for board in boards:
    title_list=[]
    content_list=[]
    count=0
    for page in range(10,100):
        main_driver.get('https://www.flyingv.cc/categories/' +board+ '/all?status=success'+'&page='+str(page))
        time.sleep(2)
        error=0
        for x in range(12):
            try:
                tmp_title = main_driver.find_element_by_xpath('//*[@id="projects"]/div/div['+str(x+1)+']/div/div[3]/p[1]')
                #tmp_title = main_driver.find_element_by_xpath('//*[@id="projects"]/div/div['+str(x+1)+']/div/div[2]/p[1]')
                tmp_content = main_driver.find_element_by_xpath('//*[@id="projects"]/div/div['+str(x+1)+']/div/div[3]/p[3]')
                title_list.append(tmp_title.get_attribute('innerHTML'))
                content_list.append(tmp_content.get_attribute('innerHTML'))
                print(title_list[count])
                print(content_list[count])
                print('\n')
                count+=1
            except Exception as e:
                print(str(e))
                error+=1
        if error>10:
            break
    with open(board+'.txt', 'w', encoding = 'utf8') as result:
        result.write(board+'\n')
        for article in range(len(title_list)):
            result.write(title_list[article] + '\n' + content_list[article] +'\n')
# Out:
# 走私成功！黑幫角色扮演桌遊【MEXICO走私】
# 甚麼樣的遊戲可以讓你和朋友盡情耍心機，放肆打嘴砲？
# 一款從遊戲、故事、美術全都由台灣團隊自行製作的遊戲，
# 【MEXICO走私】希望可以找回你與朋友間互動的溫度。
#
#
# 【ARMOUR Cardholder】暮樂生活-優雅真皮卡套及工具卡
# ARMOUR Cardholder 多功能卡套，使用頂級的義大利手染軟皮，極佳的觸感加上手工染色氣質，讓卡夾外型優雅經典。搭配不鏽鋼工具卡設計，保護卡片不折彎受損外更可輕鬆解決生活中常發生的小問題。
#
#
# 《Pentheon 420》 Semitone時尚球型 2.0 音響
# Semitone 2015推出第一款的時尚球音響, 我們希望以2.0聲道Pentheon 420與各位見面, 主要發現音響市場客群中, 很多人有隨身藍芽音響產品, 雖方便攜帶但或許無法聽見真正好聲音,在您思考擁有人生第一款類Hifi級入門品時, Semitone希望大家都可在居家營造設計美學與音感的空間, 並且以合理的價格享受這樣優質的好聲音！
#
#
# 美肌刻sport 強力壓縮腿套開發計畫
# 本計畫預計開發出一改良型的壓縮腿套(compression calf sleeves)，供喜愛運動的人尤其是跑者使用，本產品運用運動貼紮膠布為動機而設計，也希望能夠透過本計畫的宣傳，讓國人更重視運動傷害的防護問題。
#
#
# 動畫儀：給孩子的第一個機械裝置
# 《動畫儀》是由綿羊犬團隊專為 3 歲以上孩子所開發的機械裝置組。相較於常見的複雜機械結構，我們將設計簡單化，讓孩子透過齒輪零件的辨認、組裝，體驗機械裝置運作的奧妙。
#
#
# DOLCE GUSTO專用●重複使用型咖啡膠囊
# 地球每年生產數億顆，不易分解與回收的拋棄式咖啡膠囊，如果你也是咖啡愛好者，請與我們一起推動重複使用型咖啡膠囊量產上市，給未來一個更潔淨的地球。
#
# ●本計畫為期40天，目標集資10萬元，用於量產Loops重複使用型咖啡膠囊。
#     本膠囊為DOLCE GUSTO全自動咖啡機專用，製程100%符合食品安全規範，
#     100%台灣製。
#
# ●本計畫到達贊助人數，將公開抽獎送DG全自動咖啡機與多色膠囊升級。
#
#
#
#
# 《活手印》用活字，說你的故事，玩你的創意！
# 親手，印下活字蘊含的意義。
# 字讓紙有了意義，紙讓字有了生命，在活手印的字槽內，自由排列組合文字，手握木頭的溫潤質感，蓋下你的隻字片語，專屬於你，獨一無二。紙片上的刻痕，一如文字在你心頭留下的足跡。活手印，讓熱愛文字的你我，藉由活字，說自己的故事。
#
#
# 織夢狼─「邋猑溪居」1周年紀念T-shirt
# 紀念「邋猑溪居」社團成立1周年，將原本單純的預購提升到募資的程度，希望大家能夠支持獨立創作的藝術家。
#
#
# LFP : 香料香水實驗室，自己的香水自己創造，由你創作專屬個人化香水
# 期望透過募資打造香水創作平台，由消費者決定香水香型的組合，並達到表現自我及個人情意的傳達，讓香水不只是香水。
# 由LFP提供調香的香味分子，並與每一位消費者溝通、討論其喜歡的香型，我們以協同創作的方式，成為每個人的創作夥伴，由消費者搭配後的香水組成，而後由我們製作並把關品質、安全性。同時，我們也將配和舉行調香工作坊，傳遞調香知識，讓消費者透過實作與討論、學習新的嗅覺體驗。
# 讓我們一起打造台灣香水創作的新環境，一個舞台邀請大家詮釋不同的自我！
#
#
#
# 安全發亮衣HunkMan-您與家人的隨身保鏢
# 開發「夜間安全守護」服飾，遠距反光的時尚服飾 貼身保護您的安全。據內政部統計，目前台灣超過2200萬輛摩托車，加上台灣是混合車流，常見機車亂竄，對於道路上的行人、慢跑者、自行車、通勤族..等，道路安全風險很高，夜晚更加危險。贊助此產品保護您與家人安全，歡迎各種合作。
#
#
#
# 汽車有安全氣囊，那機車呢?
# 安全氣囊不再只是汽車的專利，騎士也應該享有相同的保障!!!
#
#
#
# 我聽。你說
# 人們總說，這塊土地上，除了美食，最美的風景便是熱情兼容的人們。
# 你知道嗎?
# 台灣有一群人，他們來自世界各地，多元的文化就此在這顆大番薯上萌芽。
# FIT想透過最間單的記錄，讓所有人擁抱最真實的彼此。
#
#
# 收藏月球表面！極仿真版月球燈
# 我們是橡果藝術工作室，期許能帶給人們最美好的生活！
#
#
# 你的愛駒是否還缺一個真正的馬鞍包 ? 馬鞍包又不只是馬鞍包!!!
# 一個有別於傳統馬鞍包的設計概念,可以是腳踏車用的馬鞍包,也可以是喜歡愜意輕裝外出的實用包。
#
#
# 解決旅行分類的貨幣包-TWIGGY第三代四國貨幣包
# 旅行也可以很時尚  ，
# 快樂、旅行、四國貨幣包，
# 顛覆旅行收納的定義，
# 一次解決各種貨幣與收據的分類混亂，
# 屬於女孩的時尚輕旅行現在開始。
#
#
#
# 【Kalight】萬花燈
# 如果有一盞燈，可以自由變化無窮無盡的景象，那將會是一道非常夢幻又浪漫的光芒。
# 變化萬千，又歸於一體，萬中選一。
# Kalight，勝過萬盞燈。
#
#
#
# 121免綁鞋帶     小發明  大方便
# ~人，都不喜歡綁鞋帶，綁鞋帶好麻煩~長長的鞋帶塞在鞋子裡又臭又髒~~
#
# 121免綁鞋帶，小發明，大方便，讓您擺脫掉鞋帶煩腦，高彈性，輕鬆穿脫，適合全家人使用。
# 希望可以將此產品推廣到更多國家，並帶動更多台灣發明、台灣製造走向全世界。
#
#
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[6]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# 聆聽幸福的聲音~Semitone Rouge1001耳機禮物
# 我們品牌取名Semitone顧名思義是希望做出好音質的設計產品,希望這個新事業未來有機會能夠為台灣音響耳機品牌盡一份心力,並且做出更多不輸國外的設計產品！本來只是希望將自己喜愛的音質做為一份送禮的禮品, 但是因緣際會下,我們夫妻決定一同打拼創業,將這樣好聽的幸福感傳遞給更多朋友！
#
#
# 【SurfAce 台灣比基尼新革命】想穿就穿，展現妳的美麗自信！
# 市面上比基尼百百款，可是想找到一件好看又好穿的怎麼這麼難？
# 妳是否也有和我們相同的困擾？
# 現在，這些問題都不再是問題了！
# SurfAce Bikini，台灣自創的比基尼品牌，強調品質、美感與安全性。
# 綜合多種貼心與獨家的設計，讓妳在展現美麗的同時，也可以放心地展現自我！
#
#
# 人人都可擁有的海底小世界--極簡易海水魚缸
# 很多人都覺得養海水魚是件很難的事，其實隨著時代的進步，養海水魚已經越來越簡單了。我們是一隻專業孵育小丑魚及其他海洋生物的團隊，在孵化後我們發現小丑魚常因為每位主人的習慣不同而有不同的命運。孵育的意義在延續既有的生命，我們打造了一個讓所有人可以輕鬆上手的海水魚缸。
#
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[10]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# 【Rangers 單車遊俠包】暮樂生活什物 - 裝載自由的騎士夢。
# 我們騎著腳踏車，馳騁在城市和鄉村，有特色的小店或是必逛景點，常想下車進去遊玩拍照，但總礙於手機錢包還放在外面腳踏車袋而玩的不盡興，最後乾脆打消念頭....
#
# 我們想做一個可以快速拆卸的單車包，騎車時可以方便的固定在車架上，離開單車又能迅速變成一款好背好看的側背包，不再有害怕東西放車上遺失，或是拎著單車包逛景點的突兀。
#
#
# 炙彘 (Pick Pigs)：五分鐘一局的派對遊戲
# 這是專門為了好友聚會以及聯誼活動而設計，一款帶有歡樂、心機與少許扮演元素的派對遊戲。簡單的策略變化與角色扮演，卻能帶出勾心鬥角的氛圍，明快又刺激的節奏，配上搞笑的自由發揮，將帶給你與好友們一個歡樂難忘的夜晚。
#
#
#
#
# 穿出你的 Style，享受你的生活
# 許多人都把網點印刷誤認為電腦直噴，實際上網點印刷可擁有顏色的亮麗與鮮豔度及不因下水洗而退色，在手感上可以兼顧膠印與布料的柔軟度，我們有三大堅持與三大保證，不只是要做好而是要做到更好。
#
#
# ZENLET -唯一帶給你簡單，安全，直覺的錢包
# 你是否曾有過站在一堆排隊的購買者前卻找不到皮包的經驗？你現在手裡的錢包是否雜物太多，卡片亂塞夾層常找不到要用的卡？你知道一般人常背部疼痛原因是來自於厚重的錢包嗎？現在，我們將顛覆錢包的設計，重新讓你思考錢包的需求與功能。
#
#
# POKE!!  機車族的必備神器-安全帽防水防塵套
# 台灣是很會下雨的國家
#
# 不但如此
#
# 又是機車族密度極高的機車王國
#
# 使用安全帽也相較於其他國家來的多。
#
# 通勤機車族都會發現一件事，就是一台機車是無法放置四分之三的安全帽兩頂，常常要有一頂犧牲掛在外面，這時若突然下大雨...安全帽就會濕透而不堪設想。
#
# 因此我們將思考如何做出一頂可以承受台灣氣候的「安全帽套」，在這雨套的設計上首先主要考量的就是【防水】、【耐磨】、【防盜】等設計
#
#
#
# 讓更多的台灣設計被全世界看見 -BRENDA x LVG
# 願意跟我們一樣用行動來支持台灣本土設計師嗎？在布蘭達與LVG的帶領之下，讓更多的台灣設計被全世界看見！
#
#
# 兩分鐘，打造你的縮時影片 FFWD
# FFWD雲端縮時攝影機，讓你用不同角度看待生活，用嶄新方式探索世界，體驗HD高畫質縮時影片帶來的視覺饗宴。從今起，縮時攝影不再需要昂貴的器材，與繁複的後製。
# 輕鬆濃縮生活片段，就從 FFWD雲端縮時攝影機開始。
#
#
#
# 《龐氏騙局》，翻轉你對桌上遊戲的想像
# 發生在1919年，金融教科書裡的經典詐欺案例。不只是作為一款「金融教育」桌遊，也不只是把背景故事貼附在遊戲機制上而已。還原事物背後的運作的邏輯，依此作為遊戲設計的基點。把現實中人們會遇到的煩惱與期待放進遊戲，讓人們像現實一樣去面對每個艱難卻意義重大的選擇。更多地方著重在「思考訓練」。只要玩家能把在遊戲「停下來，想一想」的習慣帶回現實當中，觀察身邊的遊戲規則是怎麼運作的，就能為這個世界帶來改變。
#
#
# so that's me × 許匡匡 衣起更好
# 這是一個畫畫的女孩與兩姊妹的服裝品牌一起做出的勇敢嘗試，希望能用最用心的設計與剪裁，讓穿上的人與看見的人都能感到溫暖和療癒的力量。
#
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[8]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# 一雙鞋，一輩子的旅行：ILIMAI x Brenda
# 鞋子是裝著你的行李箱，更是貼心的好夥伴。
#
#
# 大女孩新生活提案-coplay設計包
# 近年台灣文創業蓬勃，開始經營自己插畫品牌的年輕插畫家越來越多，身為台灣在地品牌，COPLAY設計包一直致力於結合台灣文化創意的理念，落實在商品呈現上。但也因為藝術文化與商業的結合，更讓我們審慎的思考，將藝術商業化的同時，如何將創作者的根本理念保留，賦予更多商業行為之外的意義，提出讓消費者期待取且認同的商品。
#
#
# 妳的衣櫃就少這件:用針織串起台灣人情味以及新銳設計力量
# 誰說插畫家只能將畫印在商品上，他們也能設計出很棒的服飾。要走出台灣，必須靠原創的力量，clotho想當強而有力的後盾，讓創作能量被凝聚成更多消費者喜愛的商品。這只是一個開始，藉由大家的認同讓這個開始能夠無限延伸。
#
#
# BLACHOICE 幾何角形杯 X 黑白筆記
# BLACHOICE 是間只有黑與白的設計專門店。除了致力於打造黑白小宇宙
# 我們正計劃推出自有的商品
# 「幾何角形杯與黑白筆記」 做喜愛黑白極簡設計的純粹選擇。
#
#
# Drifter 傳承革製手藝不失傳
# 透過你的支持，這些精湛的革製手藝，以及灌入傳統靈魂的皮件，將裝載著滿滿的熱情及動人的生命態度，實現不一樣的希望與夢想，走入世界的中心。
#
#
# Lulu's Hand - 讓人人都可以沖出好咖啡
# 一個由台灣原創設計的咖啡沖泡濾杯，改進手沖精品咖啡的沖泡方式，省去了濾紙保留了更多原味與香氣，透過嶄新的機構設計，讓人人都可以簡單的沖出好咖啡。《Lulu's Hand》
#
#
# 你需要更好的，皮器。
# 現代人生活壓力大，時常會有爆氣的衝動；
# 我們需要時間放鬆一下享受生活，活出品味。
#
# 以質感的皮件為出發點套用在生活中，
# 隨時提醒自己，注意一下自己的，好皮器。
#
#
# 【新台灣合作運動】識別體系
# 發起【新台灣合作運動～台灣要合不要分】，建立識別體系，設計【TWT台灣T恤～手足紀念款】，期能透過贊助專案加以生產，讓認同【新台灣合作運動】理念的人，能自發性穿上這款紀念T恤，在生活中傳遞【台灣要合不要分】訊息，影響更多人加入這個柔性的公民運動。
#
#
# SpotCam - 專為家用環境設計的WiFi影像監控雲端攝影
# CCTV系統需要複雜的主機接線和網路設定，市面上號稱雲端的攝影機又只能使用智慧型手機或平板觀看，且多無法錄影及回放。我們希望開發一款真正結合雲端，用行動裝置、筆電或桌機都可以觀看和回放，簡單易用的WiFi攝影機。
#
#
# AIESEC 盛夏海灘巾（經典復刻版）
# 夏天到了！
# 今年夏天台灣AIESEC很熱鬧！
# 今年剛好 IC (International Congress) 跟 AAGC (AIESEC Alumni Global Conference) 都在台灣舉辦，
# 我們想起0809年也在台灣舉辦的HEROES，
# 當年不只會議舉辦得很成功，
# 還出了秒殺海灘巾！
# 連不少當年有參加會議的人都沒有搶購到而因此扼腕～
#
# 因此我們決定趁勢推出經典復刻版AIESEC海灘巾，
# 不管是現任 Elected 參加 IC，還是骨頭參加 AAGC，
# 讓AIESEC填滿你今年的夏天吧！
#
#
# 禾作 – 以稻殼觸動食物情感的餐墊
# 稻殼原本是農業廢棄物，我們將原本無經濟作用的稻殼重新利用，讓它與紙漿混合成全新材質，設計出首款「禾作」餐墊系列商品。我們想傳達的不只是真正以禾製作的概念，還有一份對於資源再利用的環保意識。
#
#
# 「友善超車，請給單車1.5M」車衣製作募款計畫
# 友善種子致力推行「友善超車，給單車1.5M」，倡導汽機車駕駛時要與單車騎士保持1.5M的安全距離這樣一個共享路權的觀念，友善種子計畫募集50萬製作大量的專屬車衣，將「友善超車，給單車1.5M」的理念散布到這個社會每個角落。
#
#
# 《終犬》，改變流浪狗一生的桌遊
# 我們是一群喜愛動物的設計系學生，設計製作了一套桌上型遊戲《終犬》，希望透過遊戲體驗的方式讓大家關心流浪犬的議題，「以認養代替購買」。
# 遊戲原型已經完成，希望透過集資使這款遊戲能夠量產。
#
#
# 上班族的小腹救星！－【力谷】呼吸運動機
# 沒時間運動嗎？運動有惰性嗎？運動可以分期嗎？本產品顛覆你所知的運動方式，讓每次呼吸都變成運動，有效輕鬆打擊肥肚腰怪；原來，雕塑身材竟然如此簡單輕鬆又有效啊！
#
#
# BASEQI：鋁合金神隱轉卡 Macbook Air / Retina 13吋 專用
# 特殊結構設計及鋁合金材質 - 提供您美觀實用的Apple Macbook Air 13吋/ Retina 13吋 儲存容量擴充產品
#
#
# 【新尺碼增加】denward ─ 極致舒適的台灣製牛仔褲
# 希望透過自創品牌denward，發揮台灣在地紡織業的實力和技術，做出台灣設計，台灣製造的高品質牛仔褲。改變各種牛仔褲的迷思，給你一件真正舒適又簡約百搭的高品質牛仔褲。
#
#
# 《雨港基隆》木質遊戲隨身碟限定版
# 我不想繼續用普通的光碟裝遊戲了！
# 那就來用USB
#
#
# SketchyNotebook
# SketchyNotebook 是一個目前在 Kickstarter募資的萬用筆記本。為了方便各位在台灣支持我們的朋友，在這裡提供一個更直接的贊助平台，感謝大家的支持！
#
#
# 幸福創造運動！
# 創造幸福的方式有很多種，但有一種特別有效，那就是「書寫感恩」，它是一種再簡單不過的記錄動作，它是一種無形的累積，更是涵養正面能量的基石。讓你我帶著《幸福觀察日誌》，一起發起「幸福創造運動」！
#
#
# The W 輕時代的皮夾
# The W： Wallet(皮夾)  ,  Well-design(好設計)  ,  social Welfare(社會福利)
#
#
# 傳承在地文化「藺一個延續」
# 草帽、草蓆為藺編技藝製造出來，如今沒落，正漸漸走上歷史。
# 將藺編技藝紀錄成圖解本，並以環保概念設計「DIY手工包」，商品為12種動物，不同編織手法，藉此傳遞藺編技藝與推廣文化。
#
#
# Clerk的路障生活  萬人紀念活動!!
# 本次紀念品募資活動,主要為了回饋粉絲們長久以來對小路障的支持,希望藉由大家一起募資,將路障紀念品做出來並送給大家!
# 募資越多，贈品越多噢！：D
#
#
# BRIGHT:全台首創JOYNFC客製化藍牙耳機
# 我們將實現台灣第一個可以客製化藍牙耳機的平台.  除了藍牙耳機本身的功能外, 在此我們會提供15個部位與13個顏色, 這樣的組合將能搭配出至少 34,522,712,000,000 多種的選擇.  Bright up your life! 享受好聲活!
#
#
# RU台灣 - 用心行銷台灣
# 融合時尚科技與互動創意的伴手禮，用心承載行銷台灣的內涵與使命，您的熱情參與將助力我們『RU台灣』原創設計開花結果，以嶄新的互動創意來行銷台灣，引導更多旅人走入台灣、深入台灣、用心感觸台灣的內在美 ！
#
#
# Qubefun  5秒變身收納利器!
# 我們是台灣「Qubefun」設計團隊，「Qubefun」是一款饒富趣味的積木收納蓋板，能讓使用者直覺的組合配件、靈活收納各種不同的生活小物，也能創作出任何天馬行空的創意造型，輕鬆改變居家氛圍，展現獨特個人風格。
#
#
# 筆箸 PenstiX --史上最迷你、精巧的隨行筷
# 「 美食天堂」台灣以美味小吃聞名於世，但每日使用並丟棄含化毒免洗筷竟超過280萬雙，嚴重危害健康且破壞環境；然而，環保筷普及的台灣，使用率卻不高，我們探究其因並嘗試設計小巧實用的簡約隨行筷，簡化「一雙筷」成「一支筆」。深切期盼未來，台灣能成為真正樂活、先進的美食國度！
#
#
# DEMON ART : metal 金屬經典鍵盤
# 繼 DEMON ART :style系列之後,DEMON ART 運用獨家專利設計,加上
# 【鋁合金CNC陽極處理機殼】【髮絲紋貼膜按鍵】【高質感背光】
# 成就了這樣的經典設計
#
#
# 【Triple S】 Smart Stand  iPhone多功能底座
# 整合了物理擴音、密封蓋、三種擺放角度於一體的多功能底座，能滿足看影片、閱讀、FaceTime的需求，也可帶進浴室聽音樂、放在車上當衛星導航及免持聽筒，簡單、實用、獨一無二，呈現給各位
#
#
# CLASSICO 牛角眼鏡x鋁盒 經典登場
# CLASSICO 是經典手工眼鏡品牌 我們計畫推出兩款不同材質的眼鏡第一款是限量天然牛角(新疆綿羊角)眼鏡，牛角搭配專利金屬Bata鈦卡榫結構，結合整塊的鋁合金削切製程的金屬鋁盒包裝。打開收藏盒的瞬間，斂聲屏氣。只能用光輝四射來形容! 第二款是手工板料（醋酸纖維）材質。我們特別為FlyingV 定製限定特別色-藍琥珀。這款使用CLASSICO最經典的框型 C3 。
#
#
# RainyWalker隨行傘
# 大家想要一把有著自我風格完全屬於自己的傘嗎?想要一把能隨時隨地放入包包中,不會被你遺忘在路邊,也不會乘你不注意時跟別人跑了,而是永遠跟隨你向前邁進不論天涯海角永不相忘的傘嗎?Rainy Walker隨行傘就是您最好的選擇~
#
#
# SNAP! 5 一秒讓你的手機變相機！
# 喜歡按下實體快門鍵的那種紮實手感嗎？懷念單手拿著相機來捕捉精采片刻的美好時光嗎？現在，SNAP! 5結合您所有的想像。為您的iPhone 5/5S裝上SNAP! 5後，您不僅可以擁有像相機一樣紮實的實體快門鍵，而且輕鬆好握，變成隨時可拍的一台好相機！
#
#
# 冬天也要罩戴不霧！- 口罩防霧氣密貼
# 冬天騎車戴口罩眼鏡總會起霧，感到困擾嗎？
# Moonana設計的防霧氣密貼可搭配任何您喜歡的口罩，讓其成為眼鏡防霧、舒適保暖、過濾性能更佳的完美口罩喔！
#
#
# 顛覆你的旅行方式──滾出趣任務手札
# 你以往出國旅行是什麼樣子？是購物、住飯店、看風景？除了物質的享受、風景的欣賞，旅行其實有更多精彩的面貌。45個有趣的旅行任務，顛覆你的旅行方式，讓你的旅程更具意義且精采難忘。
#
#
# DEMON ART , 你的專屬個性鍵盤
# 【 屬於你的色彩！DEMON ART 你的專屬個性鍵盤 】 厭倦一成不變的鍵盤了嗎 ? 想讓鍵盤更有自己的品味和風格嗎? DEMON ART 鍵盤 總共有 58 種色彩變化 , 就是現在 , 跟我們一起 “ 為自己訂做一個與眾不同的鍵盤吧 “
#
#
# 生活的態度，決定地球的溫度：OEM輪胎包
# OEM以友善地球、友善周遭人、事、物的品牌精神，將廢棄的各式車種內胎剪出特有胎痕的布料，縫製出專屬於你，獨一無二的高質感包款！
#
#
# SNT Fashion: 全新女性運動內衣新登場
# SNT Fashion以現代女性為發想靈感，創造舒適簡約的都會休閒風格。妳再也不需因為休閒元素而妥協對於美感、方便性與舒適性的要求。我們支持在地化的台灣優良品質，同步放眼世界，領先潮流。
#
#
# 時光
# 「時光」是一個兼具互動性與裝飾燈光的創新時鐘，結合時鐘與燈光，運用光的陰影創造出時鐘的刻度與指針，下方電線為插頭兼開關，把開關輕輕按下便可開關「時光」。
#
#
# Lomography Petzval 85 人像鏡頭
# Lomography 將帶領您進入一場攝影的時空之旅，一顆存在於 19 世紀的鏡頭，即將現身於 21 世紀，並適用於 Nikon F 接環與 Canon EF 接環的單眼相機。
#
#
# 灰設素Gray Color : Q Note 矽膠筆記本
# 擺脫平乏無奇的生活，讓Q Note豐富你我的每一天。跳脫自我侷限，相信自我的創造能力，每個人都會是獨一無二的！
#
#
# EZ 3D-Printer：台灣第一台自產自製3D印表機
# 台灣第一台完全自主研發、設計、製造的3D印表機團隊，本次將用最優惠的價格集資預購提供兩種不同的產品，更將與flyingV合作，在北中南三地提供完整的售後教學與服務。
#
#
# 器研所Gearlab：New UrbanBike
# 感謝大家大力支持，短短十天之內就完成20台預購，由於詢問過於熱烈， 我們決定再度開放20台，第二批預購我們稍微調高五千元，不過還加送設計師神祕禮物，有興趣的朋友動作要快喔。
#
#
# Mandora第一波周邊商品製作計畫
# 雷亞遊戲是以純軟體開發為主力的小團隊，但《Mandora》超過400萬的玩家給了我們強大的信心和動力，我們希望藉由Flying V這個平台，由贊助回饋的方式，挑戰製作周邊商品這項艱鉅的任務。
#
#
# SkullTwo骨小兔品牌誕生計畫
# 2012秋有2個開始，2個30歲老男孩變成爸爸，離開原有框架開始新旅程，從骨子裡透出的堅持，在激盪下幻化成一個品牌，Listen to the sound within‧
#
#
# GreenWood 第二代防水防撕摺疊卡片袋
# 這是一個台灣袋包品牌 GreenWood 進軍世界的計畫。GreenWood希望能用獨特的品味感動國內外的消費者，我們已經跨出第一步了，現在需要你們的支持推動GreenWood繼續走向全世界!!
#
#
# DrawFun網路創意服飾平台
# DrawFun就是畫畫的樂趣，記得小時候在課本上塗鴉的開心嗎？純粹的心情用畫筆呈現，我們致力於建立一個更好的創作環境,支持我們喜歡的設計師和圖案，讓畫畫變成一件值得支持的事!Just draw it!
#
#
# DolDolQ 卡娃伊 - 「卡片。娃娃。與伊人的愛。」
# 在這可愛的季節，別忘了送上可愛的Q娃和Q卡，任意時刻都可以透過 DolDolQ App 傳遞滿滿的祝福唷!
#
#
# THE BOX! 台灣系列巧食包
# THE BOX! 把美食帶著走！我們創造了巧食包，從畢展發表至今，經過材料上的更動，實用性加強及改善，第一波的產品是以台灣的美食發想，製作最具台灣味的包包，誠摯邀請您帶回這屬於台灣的食尚...
#
#
# 紙箱新型手足球台
# 這是一個簡單適合兩個人玩的小型桌上球類運動,難度不高,考驗玩家的反應和手眼協調.透過這個設計,可以讓大人小孩不分年齡,一起同樂.希望能在台灣推廣這個簡單的遊戲.
#
#
# ch+u：超電能飛行腕錶
# 預告了將近半年，中間收到了不下上百次讀者的熱情詢問，我們也都戰戰兢兢的回覆，為了呈現出最好的品質在大家面前，這隻腕錶上所有的細節我們都花了很多時間反覆檢視，試用; 從第一隻sample到現在最新的版本，大大小小的修改總共超過了30項，花費了超過一年的時間，為的就是把這支 ch+u 心目中最理想的腕錶介紹給所有的時尚愛好者。
#
#
# 圓夢50計畫－許願石與重複的力量
# 莎士比亞曾說：｢斧頭雖小，但多劈幾次，就能將堅硬的樹木伐倒｣。圓子夢希望提供給有夢想的人每人一個許願石與兩個月的Dream Partner服務，幫助更多人完成夢想。
#
#
# 食量控制餐具：Bon Appétit
# 現代的人對於審美觀相當重視，對於自己的外表更是嚴苛，而肥胖，是多數的人面臨的問題。我們發現，飲食的管理及適當的運動，才是真正能健康恢復苗條身材的不二法門。
# 藉由視覺，讓使用者看得開心，也吃的放心。
#
#
# 打造你專屬的超能心臟
# 不需要突變基因、不需要神族血統，只要無限的想像和一點時間就足以讓你成為超級英雄！
#
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[1]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[2]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[3]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[4]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[5]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[6]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[7]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[8]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[9]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[10]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[11]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div/div[12]/div/div[3]/p[1]"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
