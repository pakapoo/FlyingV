# %%
import csv
import jieba
import jieba.posseg as pseg

jieba.set_dictionary('dict.txt.txt')
with open("flyingV_money.csv", "r", encoding="utf16" ) as csvFile:
    rows=csv.DictReader(csvFile, delimiter="\t")
    dictionary_title={'eng' : 0}
    dictionary_prob={'eng' : 0}
    document_num=0
    for row in rows:
        words=pseg.cut(row['title'])
        count=0
        length=0
        dictionary_temp={'eng' : 0}
        for word in words:
            if(word.flag!='x'):
                length+=1
            ###統計該標題的各詞性出現次數###
            if(word.flag=='eng'):
                dictionary_temp['eng']+=1
            elif(word.flag[0] not in dictionary_temp):
                dictionary_temp[word.flag[0]] = 1
            else:
                dictionary_temp[word.flag[0]] += 1
            ###統計開頭的字之詞性###
            if count==0 and word.flag!='x':
                #print(word.word +" "+ word.flag)
                count+=1
                if(word.flag=='eng'):
                    dictionary_title['eng']+=1
                    print('eng', " ", row['title'])
                else:
                    if(word.flag[0] not in dictionary_title):
                        dictionary_title[word.flag[0]]=1
                    else:
                        dictionary_title[word.flag[0]]+=1
        ###更新dicitonary_prob的機率###
        for category in dictionary_temp:
            if(category!='x' and length!=0):
                dictionary_temp[category]/=length
                if(category not in dictionary_prob):
                    dictionary_prob[category]=dictionary_temp[category]
                else:
                    dictionary_prob[category]+=dictionary_temp[category]
        if(length!=0):
            document_num+=1
            
dictionary_title['others'] = 0  
dictionary_prob['others'] = 0 
temp_list = []
temp = 0
for category in dictionary_title:
    dictionary_title[category] = round(dictionary_title[category]/document_num, 2)
    if(dictionary_title[category] < 0.03 and category!='others'):
        dictionary_title['others']+=dictionary_title[category]
        temp_list.append(category)
        temp = dictionary_title['others']
dictionary_title['others'] = round(temp, 2)
for delete_item in temp_list:
    del dictionary_title[delete_item]
    
temp_list = []
for category in dictionary_prob:
    dictionary_prob[category] = round(dictionary_prob[category]/document_num, 2)
    if(dictionary_prob[category] < 0.03 and category!='others'):
        dictionary_prob['others']+=dictionary_prob[category]
        #print(dictionary_prob[category], " ", dictionary_prob['others'])
        temp_list.append(category)
        temp = dictionary_prob['others']
dictionary_prob['others'] = round(temp, 2)
for delete_item in temp_list:
    del dictionary_prob[delete_item]
    
print("--------All--------")
###標題開頭各詞性出現的機率###
print("標題開頭各詞性出現的機率 : ", dictionary_title)
###標題內各詞性出現的機率###
print("標題內各詞性出現的機率 : " ,dictionary_prob)
print('\n')
# Out:
# Building prefix dict from C:\Users\Mark\dict.txt.txt ...
# Loading model from cache C:\Users\Mark\AppData\Local\Temp\jieba.uf7b689d163b589552194008963a1d7d4.cache
# Loading model cost 1.989 seconds.
# Prefix dict has been built succesfully.
# eng   FlexPack｜摺疊防盜手提包&多功能防盜後背包
# eng   Wonder 輕玩包｜自由拆卸、輕鬆變身，給你不設限的好生活
# eng   Vinaera Pro 全球第一支「可調節式」電子醒酒器
# eng   | 經典重現 | Diana Instant Square 方形拍立得
# eng   FNG寶特袋｜100%回收寶特瓶製作｜回收者友善收購計劃
# eng   Instant Magny 35 - 135 單眼及旁軸底片相機專用拍立得機背
# eng   【eterno】LazyBallForPets 寵物懶骨頭｜征服主子的慵懶好物
# eng   END OF FEUDAL - 閣樓工作室
# eng   Ai防弊手遊－天下麻將
# eng   《Coding Forest 寇丁森林》_讓你邊玩桌遊邊學程式
# eng   【Circus Puppy-豆吉的馬戲團】台灣原創桌上遊戲
# eng   異族爭霸Throne of the world
# eng   《諾亞：Nawiat》
# eng   ATS元元 創世神伺服器 半年設備租金募資
# eng   《MR. ABOO Town》預售及周邊產品計畫
# eng   《Riddle 4 : 謎走時空》
# eng   World Arena - iPhone Game
# eng   WuTalk！台南在地誌首發實體刊物－《六分之一個＿工作天—青年路勞動日常》
# eng   《 Luna 之森》繪本募資計畫｜關於思念的療癒之書
# eng   「動漫遊戲 VS 地產霸權！地表最強募資！」超級香港故事：光輝歲月
# eng   RPG遊戲 - Crescent －新月－ 幕後漫畫與設定集支援計畫
# eng   EVERYONE'S DIARY 畫展經費籌募!!
# eng   IN.NOTES堅持雙語出版向世界廣播台灣劇場的專業
# eng   LAST: 愛藝享，讓你充滿愛與回憶的照片，轉化為獨一無二的藝術品，並在生活中分享。
# eng   DANCESPORT 國標生活誌
# eng   Mr.scissors & Ms.paper剪紙創作
# eng   Anido ㄚ泥豆 一本給小朋友和大人看的插畫類雜誌
# eng   Freedom Map 免費旅遊雜誌計畫
# eng   小資,SOHO賺外快計畫
# eng   In Sight 3.0
# eng   《VAST環島衝浪募資》接力傳承台灣之美
# eng   【Learn in Africa】UWC學費募資計畫-勇闖史瓦濟蘭，非洲我來啦!
# eng   Wootso-騖笑的臺灣之旅
# eng   【Salitung 我們的畢旅】南投縣信義鄉豐丘國小
# eng   Take Nemo Home：東北角小丑魚復育計劃
# eng   Lightening Dark 從非洲看見台灣
# eng   《Misa-Lisin彌莎．禮信》 冉而山劇場虔敬愛丁堡藝穗節-募資計劃
# eng   flyingV bus
# eng   愛爾蘭-Stayhold-車用後廂止滑定位擋板
# eng   【wunDoo】我們要用「旅行」這件事，點亮台灣的每個角落，翻轉鄉鎮和部落
# eng   鄉村FARMER夢~找回大地的孩子
# eng   建築進化論 The Life We Made - BIG team 丹麥綠建築參訪計畫
# eng   LOVE Taiwan 還愛台灣
# eng   Life is calling— 印尼、印度海外服務學習計劃
# eng   HelloCities青年旅行家之 {紐約，我要讓你看到台灣}募款計畫
# eng   Cheers Taiwan！鍥而不捨，台灣划出去！
# --------All--------
# 標題開頭各詞性出現的機率 :  {'eng': 0.19, 'n': 0.35, 'a': 0.05, 'v': 0.14, 'm': 0.07, 'p': 0.03, 'z': 0.05, 'u': 0.03, 'd': 0.03, 'others': 0.05}
# 標題內各詞性出現的機率 :  {'eng': 0.12, 'n': 0.38, 'a': 0.04, 'v': 0.17, 'u': 0.06, 'm': 0.06, 'z': 0.04, 'others': 0.11}

# %%
import csv
import jieba
import jieba.posseg as pseg
status_list = ['success', 'unsuccess']
save_list = ['eng', 'n', 'a', 'v', 'm', 'z']
jieba.set_dictionary('dict.txt.txt')

for status in status_list:
    with open("flyingV_money.csv", "r", encoding="utf16" ) as csvFile:
        rows=csv.DictReader(csvFile, delimiter="\t")
        dictionary_title={'eng' : 0}
        dictionary_prob={'eng' : 0}
        document_num=0
        for row in rows:
            if(row['statis'] == status):
                words=pseg.cut(row['title'])
                count=0
                length=0
                dictionary_temp={'eng' : 0}
                for word in words:
                    if(word.flag!='x'):
                        length+=1
                    ###統計該標題的各詞性出現次數###
                    if(word.flag=='eng'):
                        dictionary_temp['eng']+=1
                    elif(word.flag[0] not in dictionary_temp):
                        dictionary_temp[word.flag[0]] = 1
                    else:
                        dictionary_temp[word.flag[0]] += 1
                    ###統計開頭的字之詞性###
                    if count==0 and word.flag!='x':
                        #print(word.word +" "+ word.flag)
                        count+=1
                        if(word.flag=='eng'):
                            dictionary_title['eng']+=1
                        else:
                            if(word.flag[0] not in dictionary_title):
                                dictionary_title[word.flag[0]]=1
                            else:
                                dictionary_title[word.flag[0]]+=1
                ###更新dicitonary_prob的機率###
                for category in dictionary_temp:
                    if(category!='x' and length!=0):
                        dictionary_temp[category]/=length
                        if(category not in dictionary_prob):
                            dictionary_prob[category]=dictionary_temp[category]
                        else:
                            dictionary_prob[category]+=dictionary_temp[category]
                if(length!=0):
                    document_num+=1
        dictionary_title['others'] = 0  
        dictionary_prob['others'] = 0 
        temp_list = []
        temp = 0
        for category in dictionary_title:
            dictionary_title[category] = round(dictionary_title[category]/document_num, 2)
            if(category not in save_list and category!='others'):
                dictionary_title['others']+=dictionary_title[category]
                temp_list.append(category)
                temp = dictionary_title['others']
        dictionary_title['others'] = round(temp, 2)
        for delete_item in temp_list:
            del dictionary_title[delete_item]

        temp_list = []
        for category in dictionary_prob:
            dictionary_prob[category] = round(dictionary_prob[category]/document_num, 2)
            if(category not in save_list and category!='others'):
                dictionary_prob['others']+=dictionary_prob[category]
                #print(dictionary_prob[category], " ", dictionary_prob['others'])
                temp_list.append(category)
                temp = dictionary_prob['others']
        dictionary_prob['others'] = round(temp, 2)
        for delete_item in temp_list:
            del dictionary_prob[delete_item]

        print("--------"+status+"--------")
        ###標題開頭各詞性出現的機率###
        print("標題開頭各詞性出現的機率 : ", dictionary_title)
        ###標題內各詞性出現的機率###
        print("標題內各詞性出現的機率 : " ,dictionary_prob)
        print('\n')
# Out:
# Building prefix dict from C:\Users\Mark\dict.txt.txt ...
# Loading model from cache C:\Users\Mark\AppData\Local\Temp\jieba.uf7b689d163b589552194008963a1d7d4.cache
# Loading model cost 1.679 seconds.
# Prefix dict has been built succesfully.
# --------success--------
# 標題開頭各詞性出現的機率 :  {'eng': 0.2, 'n': 0.36, 'a': 0.05, 'v': 0.13, 'm': 0.07, 'z': 0.04, 'others': 0.11}
# 標題內各詞性出現的機率 :  {'eng': 0.12, 'n': 0.39, 'a': 0.04, 'v': 0.17, 'm': 0.06, 'z': 0.04, 'others': 0.18}
#
#
# --------unsuccess--------
# 標題開頭各詞性出現的機率 :  {'eng': 0.18, 'v': 0.14, 'n': 0.34, 'z': 0.05, 'a': 0.05, 'm': 0.07, 'others': 0.13}
# 標題內各詞性出現的機率 :  {'eng': 0.12, 'v': 0.17, 'a': 0.04, 'n': 0.38, 'm': 0.06, 'z': 0.05, 'others': 0.18}
